# %% [markdown]
# <a href="https://colab.research.google.com/github/RafaelZanette/Projeto-integrador-2021-IoT-/blob/main/extrair_dados_receita_federal_com_api_e_cnpj.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Este projeto objetiva extrair dados da receita federal usando uma API publica e CNPJ (Cadastro Nacional de Pessoas Jurídicas).
#
# API utilizada: https://receitaws.com.br/#section-api

# %%
#Importando Bibliotecas
import requests
import re
import pandas as pd
import json
import time

# %%
#Importando a base de dados
#Importar um arquivo com uma coluna chamada "cnpj" com os CNPJs que deseja extrair os dados.
#A coluna deve estar em formato de texto e sem pontos e barras (atentar para o Excel não tirar os zeros a esquerda)
db = pd.read_excel("/content/db_cnpj.xlsx", dtype={'cnpj':'category'})
db
# Out:
#              cnpj
# 0  28850659000580
# 1  19068101000122
# 2  34701662000100
# 3  16840128000101
# 4  02645774000103

# %%
"""Extraindo dados da Receita Federal do Brasil usando o CNPJ e a API (https://receitaws.com.br/#section-api)
A API fornecida pela empresa receitaws permite a extração de dados gratuitamente, mas de maneira limitada a
130.000 consultas com 3 extrações por minuto, por essa razão é necessário usar uma pausa com o função "Time",
resultando assim em um alto tempo de operação """
lista_1 = []
lista_2 = []
lista_3 = []
lista_4 = []
lista_5 = []
lista_6 = []
lista_7 = []
lista_8 = []
lista_9 = []
lista_10 = []
lista_11 = []
lista_12 = []
lista_13 = []
cont = 0
db_1 = db[:]
for i in db_1['cnpj']:
  print(i)
  cont=cont+1
  print(cont)
  url= 'https://receitaws.com.br/v1/cnpj/{}'.format(i)
  querystring = {"A867D2F5-D434-442F-9ACF-90CCCFF13836"}
  response = requests.request("GET", url)
  resp = json.loads(response.text)
  lista_1.append(resp['situacao'])
  lista_2.append(resp['nome'])
  lista_3.append(resp['fantasia'])
  lista_4.append(resp['logradouro'])
  lista_5.append(resp['numero'])
  lista_6.append(resp['complemento'])
  lista_7.append(resp['bairro'])
  lista_8.append(resp['cep'])
  lista_9.append(resp['municipio'])
  lista_10.append(resp['email'])
  lista_11.append(resp['telefone'])
  lista_12.append(resp['motivo_situacao'])
  lista_13.append(resp['data_situacao'])
  time.sleep(20)
db_1['situacao'] = lista_1
db_1['nome'] = lista_2
db_1['fantasia'] = lista_3
db_1['logradouro'] = lista_4
db_1['numero'] = lista_5
db_1['complemento'] = lista_6
db_1['bairro'] = lista_7
db_1['cep'] = lista_8
db_1['municipio'] = lista_9
db_1['email'] = lista_10
db_1['telefone'] = lista_11
db_1['motivo_situacao'] = lista_12
db_1['data_situacao'] = lista_13

db_1
# Out:
# 28850659000580
# 1
# 19068101000122
# 2
# 34701662000100
# 3
# 16840128000101
# 4
# 02645774000103
# 5
# <ipython-input-32-3fd7423bb77a>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   db_1['situacao'] = lista_1
# <ipython-input-32-3fd7423bb77a>:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   db_1['nome'] = lista_2
# <ipython-input-32-3fd7423bb77a>:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   db_1['fantasia'] = lista_3
# <ipython-input-32-3fd7423bb77a>:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   db_1['logradouro'] = lista_4
# <ipython-input-32-3fd7423bb77a>:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   db_1['numero'] = lista_5
# <ipython-input-32-3fd7423bb77a>:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   db_1['complemento'] = lista_6
# <ipython-input-32-3fd7423bb77a>:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   db_1['bairro'] = lista_7
# <ipython-input-32-3fd7423bb77a>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   db_1['cep'] = lista_8
# <ipython-input-32-3fd7423bb77a>:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   db_1['municipio'] = lista_9
# <ipython-input-32-3fd7423bb77a>:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   db_1['email'] = lista_10
# <ipython-input-32-3fd7423bb77a>:51: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   db_1['telefone'] = lista_11
# <ipython-input-32-3fd7423bb77a>:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   db_1['motivo_situacao'] = lista_12
# <ipython-input-32-3fd7423bb77a>:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   db_1['data_situacao'] = lista_13
#              cnpj situacao                                 nome  \
# 0  28850659000580    ATIVA  K S ESPORTE, CULTURA E TURISMO LTDA
# 1  19068101000122    ATIVA                 VIACAO AROEIRAS LTDA
# 2  34701662000100    ATIVA               ARAUJO E BERNARDO LTDA
# 3  16840128000101    ATIVA     YOROZU AUTOMOTIVA DO BRASIL LTDA
# 4  02645774000103    ATIVA     AMALU INDUSTRIA E COMERCIO LTDA.
#
#                     fantasia                logradouro  numero  \
# 0  K S BEACH HOTEL RESIDENCE             EST DO PONTAL    8000
# 1            VIACAO AROEIRAS       AVENIDA SANTA CLARA      05
# 2      UNIVERSO DOS SALGADOS  RUA AURELIO JOSE MARQUES     102
# 3                                            AV NISSAN  1500 C
# 4                                R AZHAURY MASCARENHAS     270
#
#                     complemento                    bairro         cep  \
# 0                                RECREIO DOS BANDEIRANTES  22.790-877
# 1                                             SANTA CLARA  65.058-544
# 2                                                  CENTRO  44.900-000
# 3                   : PORTAO 6;           POLO INDUSTRIAL  27.537-800
# 4  LOTE 2 LTM 35779 QDR A PARTE              CAMPO GRANDE  23.078-520
#
#         municipio                        email  \
# 0  RIO DE JANEIRO
# 1        SAO LUIS  viacao.aroeiras@hotmail.com
# 2           IRECE       contec_con@hotmail.com
# 3         RESENDE     margaretep@yorozu.com.br
# 4  RIO DE JANEIRO  legalizamorumbi@solutta.com
#
#                          telefone motivo_situacao data_situacao
# 0                  (21) 2525-0900                    28/10/2015
# 1                  (98) 3248-3888                    07/10/2013
# 2                  (74) 9939-8327                    29/08/2019
# 3  (24) 3358-1051/ (24) 8186-0007                    12/09/2012
# 4                  (11) 4504-7000                    15/09/2001

# %%
#Organizando as colunas de dados
db_1 = db_1[['cnpj','situacao','motivo_situacao', 'data_situacao','nome','fantasia','logradouro','numero','complemento','bairro','cep','municipio','email','telefone']]
db_1
# Out:
#              cnpj situacao motivo_situacao data_situacao  \
# 0  28850659000580    ATIVA                    28/10/2015
# 1  19068101000122    ATIVA                    07/10/2013
# 2  34701662000100    ATIVA                    29/08/2019
# 3  16840128000101    ATIVA                    12/09/2012
# 4  02645774000103    ATIVA                    15/09/2001
#
#                                   nome                   fantasia  \
# 0  K S ESPORTE, CULTURA E TURISMO LTDA  K S BEACH HOTEL RESIDENCE
# 1                 VIACAO AROEIRAS LTDA            VIACAO AROEIRAS
# 2               ARAUJO E BERNARDO LTDA      UNIVERSO DOS SALGADOS
# 3     YOROZU AUTOMOTIVA DO BRASIL LTDA
# 4     AMALU INDUSTRIA E COMERCIO LTDA.
#
#                  logradouro  numero                   complemento  \
# 0             EST DO PONTAL    8000
# 1       AVENIDA SANTA CLARA      05
# 2  RUA AURELIO JOSE MARQUES     102
# 3                 AV NISSAN  1500 C                   : PORTAO 6;
# 4     R AZHAURY MASCARENHAS     270  LOTE 2 LTM 35779 QDR A PARTE
#
#                      bairro         cep       municipio  \
# 0  RECREIO DOS BANDEIRANTES  22.790-877  RIO DE JANEIRO
# 1               SANTA CLARA  65.058-544        SAO LUIS
# 2                    CENTRO  44.900-000           IRECE
# 3           POLO INDUSTRIAL  27.537-800         RESENDE
# 4              CAMPO GRANDE  23.078-520  RIO DE JANEIRO
#
#                          email                        telefone
# 0                                               (21) 2525-0900
# 1  viacao.aroeiras@hotmail.com                  (98) 3248-3888
# 2       contec_con@hotmail.com                  (74) 9939-8327
# 3     margaretep@yorozu.com.br  (24) 3358-1051/ (24) 8186-0007
# 4  legalizamorumbi@solutta.com                  (11) 4504-7000

# %% [markdown]
# Com os dados extraidos, os próximos passos se referem a exportar-los para Google Planilhas

# %%
#Instalando a biblioteca Gsprerad
# !pip install gspread
# Out:
# Requirement already satisfied: gspread in /usr/local/lib/python3.10/dist-packages (6.0.2)
# Requirement already satisfied: google-auth>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from gspread) (2.27.0)
# Requirement already satisfied: google-auth-oauthlib>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from gspread) (1.2.0)
# Requirement already satisfied: StrEnum==0.4.15 in /usr/local/lib/python3.10/dist-packages (from gspread) (0.4.15)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth>=1.12.0->gspread) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth>=1.12.0->gspread) (0.4.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth>=1.12.0->gspread) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib>=0.4.1->gspread) (1.3.1)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth>=1.12.0->gspread) (0.6.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (3.2.2)
# Requirement already satisfied: requests>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (2024.6.2)

# %%
#Importando bibliotecas
from google.colab import auth
from google.auth import default
import gspread

# %%
#Fazendo autenticação
#Nessa etapa será necessário selecionar uma conta Google e aceitar/permitir o acesso.
auth.authenticate_user()
creds, _= default()
gc = gspread.authorize(creds)

# %%
#Trabalhando na planilha Google Sheets
planilha =  gc.open("nome da planilha")# Colocar entre os parenteses e aspas o nome da planilha que está no Google Sheets e para onde os dados serão extraídos
aba1= planilha.sheet1

# %%
#Exportando a planilha
aba1.update([db_1.columns.values.tolist()]+db_1.values.tolist())
# Out:
# {'spreadsheetId': '1jZ85f_FoWITPClSUGjTPWJoNR2LodVgvDxzVf5sgqyo',
#  'updatedRange': "'Página1'!A1:N6",
#  'updatedRows': 6,
#  'updatedColumns': 14,
#  'updatedCells': 84}
